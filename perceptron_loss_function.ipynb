# %%
from sklearn.datasets import make_classification
import numpy as np

X, y = make_classification(n_samples=100, n_features=2, n_informative=1, n_redundant=0, random_state=41, n_classes=2, n_clusters_per_class=1, hypercube=False)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter', s=100)

# %%
def perceptron(X, y):
    w1=w2=b=1
    lr = 0.1

    for j in range(1000):
        for i in range(X.shape[0]):
            z = w1*X[i][0] + w2*X[i][1] + b

            if z*y[i] < 0:
                w1 += lr * X[i][0] * y[i]
                w2 += lr * X[i][1] * y[i]
                b += lr * y[i]

    return w1,w2,b

# %%
w1, w2, b = perceptron(X, y)

# %%
b
# Out:
# np.float64(1.4000000000000004)

# %%
m = -w1/w2
c = -b/w2

print(m, c)
# Out:
# -2.097667976089418 -3.7202597722707997

# %%
x_input = np.linspace(-3, 3, 100)
y_input = m*x_input + c

plt.figure(figsize=(10, 6))
plt.plot(x_input, y_input, color='red', linewidth=2)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter', s=100)
plt.ylim(-3, 2)
plt.show()
